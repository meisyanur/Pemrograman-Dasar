# %% [markdown]
# <a href="https://colab.research.google.com/github/meisyanur/Pemrograman-Dasar/blob/main/Praktikum_09.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import pandas as pd

city_names = ['Jakarta', 'Bandung', 'Makassar', 'Surabaya', 'Medan', 'Yogyakarta', 'Malang']
population = [498044, 964254, 491918, 8398748, 653115, 883305, 744955]
num_airports = [2, 2, 8, 3, 1, 3, 2]

df = pd.DataFrame({
    'City Name': city_names,
    'Population': population,
    'Airports': num_airports,
})

df
# Out:
#     City Name  Population  Airports
# 0     Jakarta      498044         2
# 1     Bandung      964254         2
# 2    Makassar      491918         8
# 3    Surabaya     8398748         3
# 4       Medan      653115         1
# 5  Yogyakarta      883305         3
# 6      Malang      744955         2

# %%
# Ringkasan statistik
df.describe()

# Rata-rata populasi
rata_rata_populasi = df['Population'].mean()
print("Rata-rata populasi:", rata_rata_populasi)

# Modus jumlah bandara
modus_airports = df['Airports'].mode()
print("Modus Airports:", modus_airports)
# Out:
# Rata-rata populasi: 1804905.5714285714
# Modus Airports: 0    2
# Name: Airports, dtype: int64

# %%
import matplotlib.pyplot as plt

df['Population'].hist()
plt.title("Distribusi Populasi Kota")
plt.xlabel("Jumlah Penduduk")
plt.ylabel("Frekuensi")
plt.show()

# %%
# Korelasi
corr_matrix = df[['Population', 'Airports']].corr()
print("Korelasi:", corr_matrix)

# Kovarian
cov_matrix = df[['Population', 'Airports']].cov()
print("Kovarian:", cov_matrix)
# Out:
# Korelasi:             Population  Airports
# Population    1.000000 -0.026109
# Airports     -0.026109  1.000000
# Kovarian:               Population       Airports
# Population  8.486123e+12 -175648.833333
# Airports   -1.756488e+05       5.333333

# %%
# Menambah kolom kategori
df['Kategori_Bandara'] = df['Airports'].apply(lambda x: 'Banyak' if x >= 3 else 'Sedikit')
df

# Rata-rata populasi per kategori
group_mean = df.groupby('Kategori_Bandara')['Population'].mean()
print(group_mean)

# Agregasi lengkap
group_agg = df.groupby('Kategori_Bandara').agg({
    'Population': ['mean', 'max'],
    'Airports': ['mean', 'count']
})
group_agg
# Out:
# Kategori_Bandara
# Banyak     3.257990e+06
# Sedikit    7.150920e+05
# Name: Population, dtype: float64
#                     Population           Airports
#                           mean      max      mean count
# Kategori_Bandara
# Banyak            3.257990e+06  8398748  4.666667     3
# Sedikit           7.150920e+05   964254  1.750000     4

# %%
import pandas as pd

body_measurement_df = pd.DataFrame.from_records((
  (2, 83.82, 8.4),
  (4, 99.31, 16.97),
  (3, 96.52, 14.41),
  (6, 114.3, 20.14),
  (4, 101.6, 16.91),
  (2, 86.36, 12.64),
  (3, 92.71, 14.23),
  (2, 85.09, 11.11),
  (2, 85.85, 14.18),
  (5, 106.68, 20.01),
  (4, 99.06, 13.17),
  (5, 109.22, 15.36),
  (4, 100.84, 14.78),
  (6, 115.06, 20.06),
  (2, 84.07, 10.02),
  (7, 121.67, 28.4),
  (3, 94.49, 14.05),
  (6, 116.59, 17.55),
  (7, 121.92, 22.96),
), columns=("age", "height_cm", "weight_kg"))

body_measurement_df
# Out:
#     age  height_cm  weight_kg
# 0     2      83.82       8.40
# 1     4      99.31      16.97
# 2     3      96.52      14.41
# 3     6     114.30      20.14
# 4     4     101.60      16.91
# 5     2      86.36      12.64
# 6     3      92.71      14.23
# 7     2      85.09      11.11
# 8     2      85.85      14.18
# 9     5     106.68      20.01
# 10    4      99.06      13.17
# 11    5     109.22      15.36
# 12    4     100.84      14.78
# 13    6     115.06      20.06
# 14    2      84.07      10.02
# 15    7     121.67      28.40
# 16    3      94.49      14.05
# 17    6     116.59      17.55
# 18    7     121.92      22.96

# %%
# Ringkasan statistik
body_measurement_df.describe()

# Rata-rata tinggi & berat
mean_height = body_measurement_df['height_cm'].mean()
mean_weight = body_measurement_df['weight_kg'].mean()
print("Rata-rata tinggi:", mean_height)
print("Rata-rata berat:", mean_weight)

# Modus umur
mode_age = body_measurement_df['age'].mode()
print("Modus umur:", mode_age)
# Out:
# Rata-rata tinggi: 100.7978947368421
# Rata-rata berat: 16.071052631578947
# Modus umur: 0    2
# Name: age, dtype: int64

# %%
import matplotlib.pyplot as plt

# Tinggi
body_measurement_df['height_cm'].hist()
plt.title("Distribusi Tinggi Badan (cm)")
plt.show()

# Berat
body_measurement_df['weight_kg'].hist()
plt.title("Distribusi Berat Badan (kg)")
plt.show()

# %%
# Mean
group_mean_age = body_measurement_df.groupby("age").mean()
group_mean_age

# Agg lengkap
group_agg_age = body_measurement_df.groupby("age").agg({
    'height_cm': ['mean', 'min', 'max'],
    'weight_kg': ['mean', 'min', 'max']
})
group_agg_age
# Out:
#       height_cm                 weight_kg
#            mean     min     max      mean    min    max
# age
# 2     85.038000   83.82   86.36   11.2700   8.40  14.18
# 3     94.573333   92.71   96.52   14.2300  14.05  14.41
# 4    100.202500   99.06  101.60   15.4575  13.17  16.97
# 5    107.950000  106.68  109.22   17.6850  15.36  20.01
# 6    115.316667  114.30  116.59   19.2500  17.55  20.14
# 7    121.795000  121.67  121.92   25.6800  22.96  28.40

# %%
# Korelasi
corr_hw = body_measurement_df[['height_cm', 'weight_kg']].corr()
print(corr_hw)

# Kovarian
cov_hw = body_measurement_df[['height_cm', 'weight_kg']].cov()
print(cov_hw)
# Out:
#            height_cm  weight_kg
# height_cm   1.000000   0.888014
# weight_kg   0.888014   1.000000
#             height_cm  weight_kg
# height_cm  166.583840  54.525886
# weight_kg   54.525886  22.632521

# %%
# Ringkasan Statistik
df.describe()

rata_rata_pembayaran = df['payment'].mean()
print("Rata-rata Nilai Pembayaran: ", rata_rata_pembayaran)

# Modus Nilai Pembayaran (Menggantikan Modus Airports)
modus_pembayaran = df['payment'].mode()
print("\nModus Pembayaran:", modus_pembayaran)
# Out:
# Rata-rata Nilai Pembayaran:  33972.936
#
# Modus Pembayaran: 0    18355
# 1    37440
# 2    37821
# 3    37878
# 4    41180
# Name: payment, dtype: int64

# %%
import matplotlib.pyplot as plt

# Asumsi df sudah berisi data dari orders.csv

plt.figure(figsize=(8, 5))
df['payment'].hist(bins=20, edgecolor='black')
plt.title("Distribusi Nilai Pembayaran (Payment)")
plt.xlabel("Nilai Pembayaran")
plt.ylabel("Frekuensi")
plt.show()

# %%
corr_matrix = df[['order_id', 'payment']].corr()
print("# Korelasi")
print("Korelasi:")
print(corr_matrix)

# Kovarian
cov_matrix = df[['order_id', 'payment']].cov()
print("\n# Kovarian")
print("Kovarian:")
print(cov_matrix)
# Out:
# # Korelasi
# Korelasi:
#           order_id   payment
# order_id  1.000000  0.021371
# payment   0.021371  1.000000
#
# # Kovarian
# Kovarian:
#               order_id       payment
# order_id  83416.666667  8.919858e+04
# payment   89198.581582  2.088490e+08

# %%
df['Kategori_Pembayaran'] = df['payment'].apply(
    lambda x: 'Besar' if x >= mean_payment else 'Kecil'
)

# Rata-rata Nilai Pembayaran per Kategori (Menggantikan rata-rata populasi)
group_mean = df.groupby('Kategori_Pembayaran')['payment'].mean()
print(group_mean)

group_agg = df.groupby('Kategori_Pembayaran').agg({
    'payment': ['mean', 'max'],
    'order_id': ['count']
})
group_agg
# Out:
# Kategori_Pembayaran
# Besar    46592.548387
# Kecil    21553.634921
# Name: payment, dtype: float64
#                           payment        order_id
#                              mean    max    count
# Kategori_Pembayaran
# Besar                46592.548387  59910      496
# Kecil                21553.634921  33908      504
